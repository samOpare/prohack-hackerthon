# %%
from zipfile import ZipFile

#unzipping the zipfile
with ZipFile("prohack_dataset.zip") as zipObj:
    fileNames = zipObj.namelist()
    for file in fileNames:
        if file.endswith(".csv"):
            zipObj.extract(file,"data")

# %% [markdown]
# ### loading the data into data frames

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor 
from sklearn.metrics import mean_squared_error
import math

train = pd.read_csv("data/train_to_download_final_1.csv")
train.head()
# Out:
#    galactic year                        galaxy  existence expectancy index  \
# 0         990025  Large Magellanic Cloud (LMC)                    0.628657
# 1         990025              Camelopardalis B                    0.818082
# 2         990025                       Virgo I                    0.659443
# 3         990025            UGC 8651 (DDO 181)                    0.555862
# 4         990025                  Tucana Dwarf                    0.991196
#
#    existence expectancy at birth  Gross income per capita  Income Index  \
# 0                      63.125200             27109.234310      0.646039
# 1                      81.004994             30166.793958      0.852246
# 2                      59.570534              8441.707353      0.499762
# 3                      52.333293                      NaN           NaN
# 4                      81.802464             81033.956906      1.131163
#
#    Expected years of education (galactic years)  \
# ...

# %%
test = pd.read_csv("data/test_to_download_final_1.csv")
test.head()
# Out:
#    galactic year         galaxy  existence expectancy index  \
# 0        1007012        KK98 77                    0.456086
# 1        1007012  Reticulum III                    0.529835
# 2        1008016  Reticulum III                    0.560976
# 3        1007012        Segue 1                    0.565910
# 4        1013042        Virgo I                    0.588274
#
#    existence expectancy at birth  Gross income per capita  Income Index  \
# 0                      51.562543             12236.576447      0.593325
# 1                      57.228262              3431.883825      0.675407
# 2                      59.379539             27562.914252      0.594624
# 3                      59.952390             20352.232905      0.837700
# 4                      55.428320             23959.704016      0.520579
#
#    Expected years of education (galactic years)  \
# 0                                     10.414164
# 1                                      7.239485
# ...

# %% [markdown]
# Exploratory Data Analysis(EDA)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

train.plot(x= "Gross income per capita", y= "y", kind = "scatter")
# plt.show()

# %%
# Exercise: try a few more plots to get a feel for what the data looks like

# %% [markdown]
# ### Prediction

# %%
# Create our model
model = RandomForestRegressor(n_estimators=200)

# Split the data into inputs (X) and desired output (y)
X, y = train[test.columns[2:]].fillna(0), train['y'].fillna(0)

# Fit the model
model.fit(X, y)

#predictions
y_pred = model.predict(X)

# Score the model
math.sqrt(mean_squared_error(y, y_pred))# squared=False tells this to return RMSE
# Out:
# 0.010435103109503536

# %%
# Get the model's predictions for the test set and add them as a column (y) to test
preds = model.predict(test[test.columns[2:]].fillna(0))
test['y'] = preds
test.head()
# Out:
#    galactic year         galaxy  existence expectancy index  \
# 0        1007012        KK98 77                    0.456086
# 1        1007012  Reticulum III                    0.529835
# 2        1008016  Reticulum III                    0.560976
# 3        1007012        Segue 1                    0.565910
# 4        1013042        Virgo I                    0.588274
#
#    existence expectancy at birth  Gross income per capita  Income Index  \
# 0                      51.562543             12236.576447      0.593325
# 1                      57.228262              3431.883825      0.675407
# 2                      59.379539             27562.914252      0.594624
# 3                      59.952390             20352.232905      0.837700
# 4                      55.428320             23959.704016      0.520579
#
#    Expected years of education (galactic years)  \
# 0                                     10.414164
# 1                                      7.239485
# ...

# %% [markdown]
# ### Submission

# %%
ss = pd.DataFrame({
    'Index':test.index,
    'pred':test['y'],
    'opt_pred':0
})
ss.head()
# Out:
#    Index      pred  opt_pred
# 0      0  0.041017         0
# 1      1  0.039073         0
# 2      2  0.039415         0
# 3      3  0.040252         0
# 4      4  0.026501         0

# %%
ss = pd.DataFrame({
    'Index':test.index,
    'pred':test['y'],
    'opt_pred':0, 
    'eei':test['existence expectancy index'] # So we can split into low and high EEI galaxies
})
# Fix opt_pred
n_low_eei = ss.loc[ss.eei < 0.7].shape[0]
n_high_eei = ss.loc[ss.eei >= 0.7].shape[0]
ss.loc[ss.eei < 0.7, 'opt_pred'] = 99 # 66*99 = 6534 - >10%, <100 each
ss.loc[ss.eei >= 0.7, 'opt_pred'] = (50000-6534)/n_high_eei # The rest to high eei gs
# Leaving 5k zillion whatsits to the admin
ss = ss.drop('eei', axis=1)
ss.to_csv('Sub_test.csv', index=False)
ss.head()
# Out:
#    Index      pred  opt_pred
# 0      0  0.041017      99.0
# 1      1  0.039073      99.0
# 2      2  0.039415      99.0
# 3      3  0.040252      99.0
# 4      4  0.026501      99.0

# %%
#n_low_eei = ss.loc[ss.eei < 0.7]
ss
# Out:
# RangeIndex(start=0, stop=890, step=1)
